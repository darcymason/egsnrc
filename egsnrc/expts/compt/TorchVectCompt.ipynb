# %%
# !python -m pip install -e drive/MyDrive/git/egsnrc
import os, sys

path = "/content/drive/MyDrive/git/egsnrc"
if path not in sys.path:
    sys.path.append(path)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/git/egsnrc
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for egsnrc
# ...

# %%
from importlib import reload

# %%
import sys
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.8/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/git/egsnrc']

# %%
import egsnrc.expts.compt.torchvect_compton as tv

# %%
reload(tv)  # whenever made changes to source
# Out:
# <module 'egsnrc.expts.compt.torchvect_compton' from '/content/drive/MyDrive/git/egsnrc/egsnrc/expts/compt/torchvect_compton.py'>

# %%
tv.main(want_gpu=True, num_particles=1_000_000)  # after adding profiler `with` contexts
# Out:
# Running on device='cuda'
# TORCHvectcompton: Starting 1_000_000 'particles'
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                             torch_compt        15.75%       6.492ms        99.91%      41.192ms      41.192ms       0.000us         0.00%      10.867ms      10.867ms             1
# ...
